# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:/Users/ragav/Desktop/PRS/JSS_scheme.csv", header=0)

# %%
data.head()
# Out:
#    S.no Financial Year           State Name   District Name  Enrolled   \
# 0     1        2018-19  Andaman and Nicobar  South Andamans          0
# 1     2        2018-19       Andhra Pradesh       Anantapur        800
# 2     3        2018-19       Andhra Pradesh          Guntur        815
# 3     4        2018-19       Andhra Pradesh        Prakasam        807
# 4     5        2018-19       Andhra Pradesh        Chittoor        740
#
#    Assessed
# 0          0
# 1        800
# 2        773
# 3        807
# 4        740

# %%
data.shape
# Out:
# (1240, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1240 entries, 0 to 1239
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   S.no            1240 non-null   int64
#  1   Financial Year  1240 non-null   object
#  2   State Name      1240 non-null   object
#  3   District Name   1240 non-null   object
#  4   Enrolled        1240 non-null   int64
#  5   Assessed        1240 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 58.2+ KB

# %%
data['Financial Year'].unique()
# Out:
# array(['2018-19', '2019-20', '2020-21', '2021-22'], dtype=object)

# %%
data['State Name'].unique()
# Out:
# array(['Andaman and Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra And Nagar Haveli And Daman And Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu And Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal'], dtype=object)

# %%
data['State Name'].nunique()
# Out:
# 34

# %%
year=data['Financial Year'].unique()
year=list(year)

# %%
state=data['State Name'].unique()
state=list(state)

# %%
list1=[]
list2=[]
list3=[]
list4=[]

for i in state:
    summ=data.loc[(data['Financial Year']=='2018-19') & (data['State Name']==i)]
    list1.append(summ['Enrolled '].sum())

# %%
list1
# Out:
# [0,
#  4762,
#  156,
#  3923,
#  9567,
#  718,
#  4792,
#  534,
#  2518,
#  602,
#  7726,
#  4055,
#  703,
#  1277,
#  2469,
#  6211,
#  6342,
#  0,
#  0,
#  20679,
#  16051,
#  1937,
#  0,
#  0,
#  660,
#  12240,
#  1387,
#  4002,
#  4329,
#  4274,
#  646,
#  34087,
#  4807,
#  5829]

# %%
len(list1)
# Out:
# 34

# %%
for i in state:
    summ2=data.loc[(data['Financial Year']=='2019-20') & (data['State Name']==i)]
    list2.append(summ2['Enrolled '].sum())
            
list2
# Out:
# [0,
#  10901,
#  570,
#  9243,
#  22708,
#  1836,
#  13483,
#  1558,
#  5487,
#  1741,
#  18640,
#  9002,
#  1400,
#  3429,
#  5383,
#  16201,
#  16247,
#  0,
#  0,
#  50449,
#  38023,
#  5387,
#  0,
#  0,
#  1800,
#  30677,
#  3434,
#  9069,
#  14244,
#  12452,
#  1631,
#  85436,
#  10776,
#  14125]

# %%
for i in state:
    summ3=data.loc[(data['Financial Year']=='2020-21') & (data['State Name']==i)]
    list3.append(summ3['Enrolled '].sum())
list3
# Out:
# [0,
#  8580,
#  0,
#  8883,
#  16314,
#  1120,
#  10480,
#  897,
#  4940,
#  1664,
#  16840,
#  8705,
#  1504,
#  3554,
#  4424,
#  15525,
#  13900,
#  0,
#  0,
#  45501,
#  35102,
#  5327,
#  0,
#  0,
#  1800,
#  25820,
#  1607,
#  9493,
#  11727,
#  8497,
#  1101,
#  77335,
#  8800,
#  10356]

# %%
for i in state:
    summ4=data.loc[(data['Financial Year']=='2021-22') & (data['State Name']==i)]
    list4.append(summ4['Enrolled '].sum())
list4
# Out:
# [900,
#  11699,
#  0,
#  9864,
#  29247,
#  1600,
#  18518,
#  2459,
#  5440,
#  1740,
#  19228,
#  8939,
#  9714,
#  2396,
#  9965,
#  18755,
#  16148,
#  0,
#  0,
#  52230,
#  38482,
#  6306,
#  0,
#  900,
#  1825,
#  40637,
#  3567,
#  12443,
#  14058,
#  10398,
#  2610,
#  88656,
#  12553,
#  13868]

# %%
alis1=[]
alis2=[]
alis3=[]
alis4=[]
for i in state:
    ass1=data.loc[(data['Financial Year']=='2018-19') & (data['State Name']==i)]
    alis1.append(ass1['Assessed '].sum())
alis1
# Out:
# [0,
#  4715,
#  156,
#  3809,
#  8594,
#  718,
#  4754,
#  534,
#  2379,
#  588,
#  7705,
#  3958,
#  639,
#  939,
#  2269,
#  6201,
#  6325,
#  0,
#  0,
#  19749,
#  13693,
#  1097,
#  0,
#  0,
#  39,
#  12203,
#  1322,
#  3961,
#  4102,
#  3505,
#  646,
#  33402,
#  4789,
#  5762]

# %%
len(alis1)
# Out:
# 34

# %%
for i in state:
    ass2=data.loc[(data['Financial Year']=='2019-20') & (data['State Name']==i)]
    alis2.append(ass2['Assessed '].sum())
for i in state:
    ass3=data.loc[(data['Financial Year']=='2020-21') & (data['State Name']==i)]
    alis3.append(ass3['Assessed '].sum())
for i in state:
    ass4=data.loc[(data['Financial Year']=='2021-22') & (data['State Name']==i)]
    alis4.append(ass4['Assessed '].sum())

# %%
df=pd.DataFrame(list(zip(state,list1,alis1,list2,alis2,list3,alis3,list4,alis4)),columns =['state', 'err18-19','ass18-19','err19-20','ass19-20','err20-21','ass20-21','err21-22','ass21-22'])

# %%
df
# Out:
#                                        state  err18-19  ass18-19  err19-20  \
# 0                        Andaman and Nicobar         0         0         0
# 1                             Andhra Pradesh      4762      4715     10901
# 2                          Arunachal Pradesh       156       156       570
# 3                                      Assam      3923      3809      9243
# 4                                      Bihar      9567      8594     22708
# 5                                 Chandigarh       718       718      1836
# 6                               Chhattisgarh      4792      4754     13483
# 7   Dadra And Nagar Haveli And Daman And Diu       534       534      1558
# 8                                      Delhi      2518      2379      5487
# 9                                        Goa       602       588      1741
# 10                                   Gujarat      7726      7705     18640
# ...

# %%
df['err_total']=df['err18-19']+df['err19-20']+df['err20-21']+df['err21-22']

# %%
df.head()
# Out:
#                  state  err18-19  ass18-19  err19-20  ass19-20  err20-21  \
# 0  Andaman and Nicobar         0         0         0         0         0
# 1       Andhra Pradesh      4762      4715     10901     10881      8580
# 2    Arunachal Pradesh       156       156       570       479         0
# 3                Assam      3923      3809      9243      9029      8883
# 4                Bihar      9567      8594     22708     21317     16314
#
#    ass20-21  err21-22  ass21-22  err_total
# 0         0       900       860        900
# 1      8555     11699     11632      35942
# 2         0         0         0        726
# 3      8879      9864      8996      31913
# 4     16300     29247     26990      77836

# %%
df['ass_total']=df['ass18-19']+df['ass19-20']+df['ass20-21']+df['ass21-22']

# %%
df.head()
# Out:
#                  state  err18-19  ass18-19  err19-20  ass19-20  err20-21  \
# 0  Andaman and Nicobar         0         0         0         0         0
# 1       Andhra Pradesh      4762      4715     10901     10881      8580
# 2    Arunachal Pradesh       156       156       570       479         0
# 3                Assam      3923      3809      9243      9029      8883
# 4                Bihar      9567      8594     22708     21317     16314
#
#    ass20-21  err21-22  ass21-22  err_total  ass_total
# 0         0       900       860        900        860
# 1      8555     11699     11632      35942      35783
# 2         0         0         0        726        635
# 3      8879      9864      8996      31913      30713
# 4     16300     29247     26990      77836      73201

# %%
df.describe()
# Out:
#            err18-19      ass18-19      err19-20      ass19-20      err20-21  \
# count     34.000000     34.000000     34.000000     34.000000     34.000000
# mean    4920.088235   4663.323529  12215.647059  12022.911765  10582.235294
# std     6993.121535   6757.727001  17319.474654  17213.480535  15616.766970
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      649.500000    600.750000   1658.500000   1513.250000   1216.000000
# 50%     3220.500000   2942.000000   7244.500000   7057.500000   6912.000000
# 75%     5573.500000   5518.750000  14214.250000  14110.750000  11415.250000
# max    34087.000000  33402.000000  85436.000000  84987.000000  77335.000000
#
#            ass20-21      err21-22      ass21-22      err_total      ass_total
# count     34.000000     34.000000     34.000000      34.000000      34.000000
# mean   10538.117647  13680.735294  13167.294118   41398.705882   40391.647059
# ...

# %%
df['err_total'].max()
# Out:
# 285514

# %%
df['difference']=df['err_total']-df['ass_total']

# %%
df.head()
# Out:
#                  state  err18-19  ass18-19  err19-20  ass19-20  err20-21  \
# 0  Andaman and Nicobar         0         0         0         0         0
# 1       Andhra Pradesh      4762      4715     10901     10881      8580
# 2    Arunachal Pradesh       156       156       570       479         0
# 3                Assam      3923      3809      9243      9029      8883
# 4                Bihar      9567      8594     22708     21317     16314
#
#    ass20-21  err21-22  ass21-22  err_total  ass_total  difference
# 0         0       900       860        900        860          40
# 1      8555     11699     11632      35942      35783         159
# 2         0         0         0        726        635          91
# 3      8879      9864      8996      31913      30713        1200
# 4     16300     29247     26990      77836      73201        4635

# %%
df
# Out:
#                                        state  err18-19  ass18-19  err19-20  \
# 0                        Andaman and Nicobar         0         0         0
# 1                             Andhra Pradesh      4762      4715     10901
# 2                          Arunachal Pradesh       156       156       570
# 3                                      Assam      3923      3809      9243
# 4                                      Bihar      9567      8594     22708
# 5                                 Chandigarh       718       718      1836
# 6                               Chhattisgarh      4792      4754     13483
# 7   Dadra And Nagar Haveli And Daman And Diu       534       534      1558
# 8                                      Delhi      2518      2379      5487
# 9                                        Goa       602       588      1741
# 10                                   Gujarat      7726      7705     18640
# ...

# %%
tam = pd.DataFrame({
    'year': ['2018-2019', '2019-2020','2019_2021', '2021-2022'],
    'enrolled': [Tamilnadu['err18-19'].to_string(index=False),Tamilnadu['err19-20'].to_string(index=False),Tamilnadu['err20-21'].to_string(index=False),Tamilnadu['err20-21'].to_string(index=False)],
    'assessed': [Tamilnadu['ass18-19'].to_string(index=False),Tamilnadu['ass19-20'].to_string(index=False),Tamilnadu['ass20-21'].to_string(index=False),Tamilnadu['ass21-22'].to_string(index=False)]
})
tam['enrolled']=tam['enrolled'].astype('int')
tam['assessed']=tam['assessed'].astype('int')

# %%
err_max=df.loc[(df['err_total']==df['err_total'].max())]
err_min=df.loc[(df['err_total']==df['err_total'].min())]
ass_max=df.loc[(df['ass_total']==df['ass_total'].max())]
ass_min=df.loc[(df['ass_total']==df['ass_total'].min())]

# %%
err_max18=df.loc[(df['err18-19']==df['err18-19'].max())]
err_max19=df.loc[(df['err19-20']==df['err19-20'].max())]
err_max20=df.loc[(df['err20-21']==df['err20-21'].max())]
err_max21=df.loc[(df['err21-22']==df['err21-22'].max())]

# %%
err_min18=df.loc[(df['err18-19']==df['err18-19'].min())]
err_min19=df.loc[(df['err19-20']==df['err19-20'].min())]
err_min20=df.loc[(df['err20-21']==df['err20-21'].min())]
err_min21=df.loc[(df['err21-22']==df['err21-22'].min())]

# %%
ass_max18=df.loc[(df['ass18-19']==df['ass18-19'].max())]
ass_max19=df.loc[(df['ass19-20']==df['ass19-20'].max())]
ass_max20=df.loc[(df['ass20-21']==df['ass20-21'].max())]
ass_max21=df.loc[(df['ass21-22']==df['ass21-22'].max())]

# %%
ass_min18=df.loc[(df['ass18-19']==df['ass18-19'].min())]
ass_min19=df.loc[(df['ass19-20']==df['ass19-20'].min())]
ass_min20=df.loc[(df['ass20-21']==df['ass20-21'].min())]
ass_min21=df.loc[(df['ass21-22']==df['ass21-22'].min())]

# %%
zero_dropout=df.loc[df['err_total']==df['ass_total']]
high_dropout=df.loc[df['difference']==df['difference'].max()]

# %% [markdown]
# # conclusions

# %%
# total consolidation
print('The state with maximun enrollment 2018-2022:',err_max['state'].to_string(index=False),",",df['err_total'].max())
print('The state with minimum enrollment 2018-2022:',err_min['state'].to_string(index=False),",",df['err_total'].min())
print('The state with maximun assessed candidates 2018-2022:',ass_max['state'].to_string(index=False),",",df['ass_total'].max())
print('The state with minimum assessed candidates 2018-2022:',ass_min['state'].to_string(index=False),",",df['ass_total'].min())
# Out:
# The state with maximun enrollment 2018-2022: Uttar Pradesh , 285514
# The state with minimum enrollment 2018-2022:      Ladakh
# Lakshadweep
#   Meghalaya , 0
# The state with maximun assessed candidates 2018-2022: Uttar Pradesh , 283854
# The state with minimum assessed candidates 2018-2022:      Ladakh
# Lakshadweep
#   Meghalaya , 0

# %%
# 2018 -2019
print('The state with maximun enrollment 2018-2019:',err_max18['state'].to_string(index=False),",",df['err18-19'].max())
print('The state with minimum enrollment 2018-2019:',err_min18['state'].to_string(index=False),",",df['err18-19'].min())
print('The state with maximum assessed 2018-2019:',ass_max18['state'].to_string(index=False),",",df['err18-19'].max())
print('The state with minimum assessed 2018-2019:',ass_min18['state'].to_string(index=False),",",df['err18-19'].min())
# Out:
# The state with maximun enrollment 2018-2019: Uttar Pradesh , 34087
# The state with minimum enrollment 2018-2019: Andaman and Nicobar
#              Ladakh
#         Lakshadweep
#           Meghalaya
#             Mizoram , 0
# The state with maximum assessed 2018-2019: Uttar Pradesh , 34087
# The state with minimum assessed 2018-2019: Andaman and Nicobar
#              Ladakh
#         Lakshadweep
#           Meghalaya
#             Mizoram , 0

# %%
# 2019 -2020
print('The state with maximun enrollment 2019-2020:',err_max19['state'].to_string(index=False),",",df['err19-20'].max())
print('The state with minimum enrollment 2019-2020:',err_min19['state'].to_string(index=False),",",df['err19-20'].min())
print('The state with maximum assessed 2019-2020:',ass_max19['state'].to_string(index=False),",",df['err19-20'].max())
print('The state with minimum assessed 2019-2020:',ass_min19['state'].to_string(index=False),",",df['err19-20'].min())
# Out:
# The state with maximun enrollment 2019-2020: Uttar Pradesh , 85436
# The state with minimum enrollment 2019-2020: Andaman and Nicobar
#              Ladakh
#         Lakshadweep
#           Meghalaya
#             Mizoram , 0
# The state with maximum assessed 2019-2020: Uttar Pradesh , 85436
# The state with minimum assessed 2019-2020: Andaman and Nicobar
#              Ladakh
#         Lakshadweep
#           Meghalaya
#             Mizoram , 0

# %%
# 2020 -2021
print('The state with maximun enrollment 2020-2021:',err_max20['state'].to_string(index=False),",",df['err20-21'].max())
print('The state with minimum enrollment 2020-2021:',err_min20['state'].to_string(index=False),",",df['err20-21'].min())
print('The state with maximum assessed 2020-2021:',ass_max20['state'].to_string(index=False),",",df['err20-21'].max())
print('The state with minimum assessed 2020-2021:',ass_min20['state'].to_string(index=False),",",df['err20-21'].min())
# Out:
# The state with maximun enrollment 2020-2021: Uttar Pradesh , 77335
# The state with minimum enrollment 2020-2021: Andaman and Nicobar
#   Arunachal Pradesh
#              Ladakh
#         Lakshadweep
#           Meghalaya
#             Mizoram , 0
# The state with maximum assessed 2020-2021: Uttar Pradesh , 77335
# The state with minimum assessed 2020-2021: Andaman and Nicobar
#   Arunachal Pradesh
#              Ladakh
#         Lakshadweep
#           Meghalaya
#             Mizoram , 0

# %%
# 2021 -2022
print('The state with maximun enrollment 2021-2022:',err_max21['state'].to_string(index=False),",",df['err21-22'].max())
print('The state with minimum enrollment 2021-2022:',err_min21['state'].to_string(index=False),",",df['err21-22'].min())
print('The state with maximum assessed 2021-2022:',ass_max21['state'].to_string(index=False),",",df['err21-22'].max())
print('The state with minimum assessed 2021-2022:',ass_min21['state'].to_string(index=False),",",df['err21-22'].min())
# Out:
# The state with maximun enrollment 2021-2022: Uttar Pradesh , 88656
# The state with minimum enrollment 2021-2022: Arunachal Pradesh
#            Ladakh
#       Lakshadweep
#         Meghalaya , 0
# The state with maximum assessed 2021-2022: Uttar Pradesh , 88656
# The state with minimum assessed 2021-2022: Arunachal Pradesh
#            Ladakh
#       Lakshadweep
#         Meghalaya , 0

# %%
print('state with zero dropout:',zero_dropout['state'].to_string(index=False))
print('state with high dropout:',high_dropout['state'].to_string(index=False),',',df['difference'].max())
# Out:
# state with zero dropout:  Chandigarh
#      Ladakh
# Lakshadweep
#   Meghalaya
# state with high dropout: Maharashtra , 5064

# %% [markdown]
# #chandigarh is considered as the state with zero drop out

# %% [markdown]
# # Diagramatic Representation

# %%
#Total enrollment 2018-22
sns.barplot(df['state'],df['err_total'])
plt.xticks(rotation=90)
plt.title("Total enrollment 2018 - 2022")
# Out:
# C:\Users\ragav\anaconda3\envs\tensorflow_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Total enrollment 2018 - 2022')

# %%
#Total number of assessed candidates 2018-22
sns.barplot(df['state'],df['ass_total'])
plt.xticks(rotation=90)
plt.title("Total number of assessed candidates 2018 - 2022")
# Out:
# C:\Users\ragav\anaconda3\envs\tensorflow_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Total number of assessed candidates 2018 - 2022')

# %%
df.boxplot(column=['err_total','ass_total'])  
plt.title('boxplot of the total number of enrolled and assesed candidates 2018-2022')
# Out:
# Text(0.5, 1.0, 'boxplot of the total number of enrolled and assesed candidates 2018-2022')

# %%
#Conclusion
tam.plot(x="year", y=["enrolled", "assessed"], kind="line")
plt.title("Graph of Tamilnadu state for all years")
# Out:
# Text(0.5, 1.0, 'graph of Tamilnadu state for all years')
